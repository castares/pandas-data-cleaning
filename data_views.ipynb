# %%
import pandas as pd
data = pd.read_csv("./cleaned_data_GSAF5.csv")

# %%
display(data)
# Out:
#       Unnamed: 0        Date  Year  Month     Hour      Place  \
# 0              0  2016.09.18  2016      9    13:00        USA
# 1              1  2016.09.18  2016      9    11:00        USA
# 2              2  2016.09.18  2016      9    10:43        USA
# 3              3  2016.09.17  2016      9  Unknown  AUSTRALIA
# 4              4  2016.09.15  2016      9  Unknown  AUSTRALIA
# ...          ...         ...   ...    ...      ...        ...
# 5847        5847  1742.12.17  1742     12  Unknown        NaN
# 5848        5848  1738.04.06  1738      4  Unknown      ITALY
# 5849        5849  1733.00.00  1733      0  Unknown    ICELAND
# 5850        5850  1721.06.00  1721      6  Unknown      ITALY
# 5851        5851  1703.03.26  1703      3  Unknown   BARBADOS
#
#                  Area  Activity  Sex Fatal (T/F)
# 0             Florida   Surfing    M           0
# 1             Florida   Surfing    M           0
# 2             Florida   Surfing    M           0
# 3            Victoria   Surfing    M           0
# 4            Victoria   Surfing    M           0
# ...               ...       ...  ...         ...
# 5847              NaN  Swimming    M           1
# 5848           Sicily  Swimming    M           1
# 5849      Bardestrand    Others  NaN         NaN
# 5850         Sardinia  Swimming    M           1
# 5851  Southwest coast  Swimming    M           0
#
# [5852 rows x 10 columns]

# %% [markdown]
# ### Analyze the data considering the sex of the attacked people

# %%
data.set_index('Sex')
display(data[(data['Sex'] != 'M') & (data['Sex'] != 'F')])

# %%
### Relation between Activity & Sex, Age, Place, Area.

#Histogram?

# %%
data['Activity'].value_counts()
